# %%
import sys, os
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
LIBRARY_PATH = '/home/iizuka/workspace/py2/lib'
PLANTCV_PATH = '/home/iizuka/workspace/py2/lib/plantcv'
sys.path.append(LIBRARY_PATH)
sys.path.append(PLANTCV_PATH)
import plantcv as pcv


IMG_DATABASE_PATH = "/home/iizuka/workspace/py2/input_imgs"
img_file = IMG_DATABASE_PATH + '/1511513007.jpg'

img = cv2.imread(img_file)

# %%
px = img[100,100]
print(px)

# %%
print(px[0])

# %%
print(img.shape)

# %%
print(img.dtype)

# %%
plt.imshow(img)

# %%
device = 0
debug = 'plot'
img = cv2.imread(img_file)
device,img1=pcv.white_balance(device,img,debug,roi=(50,0,1000,600))

# %%
plt.imshow(img1)

# %%
b, g, r = cv2.split(img1)
print(r[80:130,600:620])

# %%
small_img = img1[80:130,600:650]
plt.imshow(small_img)
print(small_img)

# %%
lower_green = np.array([8,20,8])
upper_green = np.array([50,150,50])
mask = cv2.inRange(img1, lower_green, upper_green)

# %%
plt.imshow(mask)

# %%
res = cv2.bitwise_and(img1,img1, mask= mask)

plt.imshow(img1)
plt.imshow(mask)
plt.imshow(res)

# %%
print(hsv[100,600][0], conver_s_v(hsv[600,100][1]), conver_s_v(hsv[600,100][2]))

# %%
def conver_s_v(val):
    return val * 100.0 / 255.0

# %%
print(conver_s_v(168))
print(conver_s_v(47))

# %%
hsv.shape
